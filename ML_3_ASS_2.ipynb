# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithin611/sample1/blob/main/ML_3_ASS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **PANDAS EX**

# %%
#Task 1,2,3
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/
food = pd.read_csv("en.openfoodfacts.org.products.tsv",sep='\t')
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Task 4
food.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
#Task 5
food.shape[0]
# Out:
# 356027

# %%
#Task 6
food.shape[1]
# Out:
# 163

# %%
#Task 7
col=food.columns
col
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
#Task 8
col=food.columns[105]
print(col)
# Out:
# -fructose_100g

# %%
#Task 9
print(type(col))
# Out:
# <class 'str'>

# %%
#Task 10
print(food.index)
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
#Task 11
a=food['product_name']
a[18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
#Task 12
s = food.isnull().any()
print(s.sum())
# Out:
# 161

# %%
#Task 13
import numpy as np
s=np.array(food.isnull().sum())
print(s)
# Out:
# [    26     26      3      3     10      0      0  17512 298313 236742
#  266068 266068  29050  29070 252728 252752 252726 330977 331015 314019
#  314026 296929 296849 296823 323537 323541 335155 356001 333525 289462
#  298326    275    275    275  72134 318851 356007 327606 327633 327607
#  139406 356027  72160  72202 185838 185838  72160 356027 349455  72160
#  356027 341699 356027 101171 227021 223338     52     52     52 252778
#  252778 280302 280302  60660 355158  76530  92204 356027 356027 356026
#  356025 356023 356026 356026 356026 356000 356001 356027 356027 356026
#  356027 332987 332952 355089 355826 355984 355938 355820 355868 356018
#  356000 356001 356002 356012 356027 356011 356027 356027 356027 212584
#  211857  76807  76841 355942 355995 355983 355749 356021 356016 355736
#  355576 135344  61866 355998 356010 356018  66288  66333 351450 218321
#  355992 348820 354555 355097 214967 344750 345102 344196 349130 350697
# ...

# %%
#Task 14
c=food.columns
sc=[food.shape[0]]*food.shape[1]
d = dict(zip(c,sc))
for i in d:
  print('Column Name :',i,'------Number of rows :',d[i])
# Out:
# Column Name : code ------Number of rows : 356027
# Column Name : url ------Number of rows : 356027
# Column Name : creator ------Number of rows : 356027
# Column Name : created_t ------Number of rows : 356027
# Column Name : created_datetime ------Number of rows : 356027
# Column Name : last_modified_t ------Number of rows : 356027
# Column Name : last_modified_datetime ------Number of rows : 356027
# Column Name : product_name ------Number of rows : 356027
# Column Name : generic_name ------Number of rows : 356027
# Column Name : quantity ------Number of rows : 356027
# Column Name : packaging ------Number of rows : 356027
# Column Name : packaging_tags ------Number of rows : 356027
# Column Name : brands ------Number of rows : 356027
# Column Name : brands_tags ------Number of rows : 356027
# Column Name : categories ------Number of rows : 356027
# Column Name : categories_tags ------Number of rows : 356027
# Column Name : categories_en ------Number of rows : 356027
# ...

# %%
#Task 15
food[108:209]
# Out:
#          code                                                url  \
# 108     36252  http://world-en.openfoodfacts.org/product/0000...
# 109     36269  http://world-en.openfoodfacts.org/product/0000...
# 110     36276  http://world-en.openfoodfacts.org/product/0000...
# 111     36986  http://world-en.openfoodfacts.org/product/0000...
# 112     38058  http://world-en.openfoodfacts.org/product/0000...
# ..        ...                                                ...
# 204  20043087  http://world-en.openfoodfacts.org/product/0000...
# 205  20043124  http://world-en.openfoodfacts.org/product/0000...
# 206  20043131  http://world-en.openfoodfacts.org/product/0000...
# 207  20044015  http://world-en.openfoodfacts.org/product/0000...
# 208  20044480  http://world-en.openfoodfacts.org/product/0000...
#
#              creator   created_t      created_datetime last_modified_t  \
# 108          tacinte  1422221701  2015-01-25T21:35:01Z      1494824741
# ...
